# %% [markdown]
# <a href="https://colab.research.google.com/github/Pramod1902/Python-for-Data-science/blob/main/LAB_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("/content/student_scores.csv")

# %%
data.head()
# Out:
#    Student_ID   Name  Math  Science  English
# 0           1   Amit  85.0     90.0     78.0
# 1           2   Neha  92.0      NaN     88.0
# 2           3  Rahul  76.0     69.0     80.0
# 3           4  Pooja  88.0     95.0      NaN
# 4           5  Karan  70.0     72.0     68.0

# %%
data.isnull().sum()
# Out:
# Student_ID    0
# Name          0
# Math          2
# Science       1
# English       2
# dtype: int64

# %%
data.fillna(data.mean(numeric_only=True), inplace=True)

# %%
data.isnull().sum()
# Out:
# Student_ID    0
# Name          0
# Math          0
# Science       0
# English       0
# dtype: int64

# %%
data.head()
# Out:
#    Student_ID   Name  Math    Science  English
# 0           1   Amit  85.0  90.000000   78.000
# 1           2   Neha  92.0  79.444444   88.000
# 2           3  Rahul  76.0  69.000000   80.000
# 3           4  Pooja  88.0  95.000000   78.375
# 4           5  Karan  70.0  72.000000   68.000

# %%
students_75 = data[(data['Math'] > 75) & (data['Science'] > 75) & (data['English'] > 75)]
display(students_75)
# Out:
#    Student_ID    Name    Math    Science  English
# 0           1    Amit  85.000  90.000000   78.000
# 1           2    Neha  92.000  79.444444   88.000
# 3           4   Pooja  88.000  95.000000   78.375
# 5           6   Meena  80.875  85.000000   79.000
# 6           7    Ravi  95.000  89.000000   92.000
# 7           8  Anjali  81.000  84.000000   78.375
